# %% [markdown]
# # OOP Problems - Operator Overloading
# ## Problem 1: Complex Number Class

# %%
class ComplexNumber:
    def __init__(self, real, imag):
        self.real = real
        self.imag = imag

    def __add__(self, other):
        return ComplexNumber(self.real + other.real, self.imag + other.imag)

    def __sub__(self, other):
        return ComplexNumber(self.real - other.real, self.imag - other.imag)

    def __repr__(self):
        return f"{self.real} + {self.imag}i"

# Test
c1 = ComplexNumber(3, 2)
c2 = ComplexNumber(1, 7)

print(f"c1 = {c1}")
print(f"c2 = {c2}")
print(f"c1 + c2 = {c1 + c2}")
print(f"c1 - c2 = {c1 - c2}")
# Out:
# c1 = 3 + 2i
# c2 = 1 + 7i
# c1 + c2 = 4 + 9i
# c1 - c2 = 2 + -5i

# %% [markdown]
# ## Problem 2: Person Class - Age Comparison

# %%
class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender

    def __gt__(self, other):
        return self.age > other.age

    def __repr__(self):
        return f"{self.name} (age {self.age})"

# Test
p1 = Person("Alice", 30, "F")
p2 = Person("Bob", 25, "M")

print(f"p1 = {p1}")
print(f"p2 = {p2}")
print(f"p1 > p2: {p1 > p2}")
print(f"p2 > p1: {p2 > p1}")
# Out:
# p1 = Alice (age 30)
# p2 = Bob (age 25)
# p1 > p2: True
# p2 > p1: False

# %% [markdown]
# ## Problem 4: Vector Class - Dot Product

# %%
class Vector:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z

    def __mul__(self, other):
        return self.x * other.x + self.y * other.y + self.z * other.z

    def __repr__(self):
        return f"Vector({self.x}, {self.y}, {self.z})"

# Test
v1 = Vector(1, 2, 3)
v2 = Vector(4, 5, 6)

print(f"v1 = {v1}")
print(f"v2 = {v2}")
print(f"v1 * v2 (dot product) = {v1 * v2}")
# Out:
# v1 = Vector(1, 2, 3)
# v2 = Vector(4, 5, 6)
# v1 * v2 (dot product) = 32

# %% [markdown]
# ## Problem 5: Circle Class - All Comparison Operators

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius

    def __lt__(self, other):
        return self.radius < other.radius

    def __gt__(self, other):
        return self.radius > other.radius

    def __eq__(self, other):
        return self.radius == other.radius

    def __ne__(self, other):
        return self.radius != other.radius

    def __ge__(self, other):
        return self.radius >= other.radius

    def __le__(self, other):
        return self.radius <= other.radius

    def __repr__(self):
        return f"Circle(radius={self.radius})"

# Test
c1 = Circle(5)
c2 = Circle(3)
c3 = Circle(5)

print(f"c1 = {c1}, c2 = {c2}, c3 = {c3}")
print(f"c1 > c2: {c1 > c2}")
print(f"c1 < c2: {c1 < c2}")
print(f"c1 == c3: {c1 == c3}")
print(f"c1 != c2: {c1 != c2}")
print(f"c1 >= c3: {c1 >= c3}")
print(f"c2 <= c1: {c2 <= c1}")
# Out:
# c1 = Circle(radius=5), c2 = Circle(radius=3), c3 = Circle(radius=5)
# c1 > c2: True
# c1 < c2: False
# c1 == c3: True
# c1 != c2: True
# c1 >= c3: True
# c2 <= c1: True

# %% [markdown]
# ## Problem 6: 2D Point Class - Euclidean Distance Comparison

# %%
import math

class Point2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def distance(self):
        return math.sqrt(self.x ** 2 + self.y ** 2)

    def __lt__(self, other):
        return self.distance() < other.distance()

    def __gt__(self, other):
        return self.distance() > other.distance()

    def __eq__(self, other):
        return self.distance() == other.distance()

    def __ne__(self, other):
        return self.distance() != other.distance()

    def __ge__(self, other):
        return self.distance() >= other.distance()

    def __le__(self, other):
        return self.distance() <= other.distance()

    def __repr__(self):
        return f"Point({self.x}, {self.y}) [dist={self.distance():.2f}]"

# Test
p1 = Point2D(3, 4)
p2 = Point2D(1, 1)

print(f"p1 = {p1}")
print(f"p2 = {p2}")
print(f"p1 > p2: {p1 > p2}")
print(f"p1 < p2: {p1 < p2}")
print(f"p1 == p2: {p1 == p2}")
# Out:
# p1 = Point(3, 4) [dist=5.00]
# p2 = Point(1, 1) [dist=1.41]
# p1 > p2: True
# p1 < p2: False
# p1 == p2: False

# %% [markdown]
# ## Problem 7: Matrix Multiplication

# %%
class Matrix:
    def __init__(self, data):
        self.data = data
        self.rows = len(data)
        self.cols = len(data[0])

    def __mul__(self, other):
        if self.cols != other.rows:
            raise ValueError("Incompatible dimensions for multiplication")
        result = [[0 for _ in range(other.cols)] for _ in range(self.rows)]
        for i in range(self.rows):
            for j in range(other.cols):
                for k in range(self.cols):
                    result[i][j] += self.data[i][k] * other.data[k][j]
        return Matrix(result)

    def __repr__(self):
        return "\n".join([str(row) for row in self.data])

# Test
m1 = Matrix([[1, 2], [3, 4]])
m2 = Matrix([[5, 6], [7, 8]])

print("m1:")
print(m1)
print("\nm2:")
print(m2)
print("\nm1 * m2:")
print(m1 * m2)
# Out:
# m1:
# [1, 2]
# [3, 4]
#
# m2:
# [5, 6]
# [7, 8]
#
# m1 * m2:
# [19, 22]
# [43, 50]

# %% [markdown]
# # Inheritance
# ## Problem 1: Vehicle, Car, Bicycle

# %%
class Vehicle:
    def drive(self):
        return "Driving a vehicle"

class Car(Vehicle):
    def drive(self):
        return "Driving a car"

class Bicycle(Vehicle):
    def drive(self):
        return "Riding a bicycle"

# Test
v = Vehicle()
c = Car()
b = Bicycle()

print(v.drive())
print(c.drive())
print(b.drive())
# Out:
# Driving a vehicle
# Driving a car
# Riding a bicycle

# %% [markdown]
# ## Problem 2: Person, Student, Employee

# %%
class Person:
    def __init__(self, name, age, address):
        self.name = name
        self.age = age
        self.address = address

    def introduce(self):
        return f"Hi, I'm {self.name}, {self.age} years old, living in {self.address}."

class Student(Person):
    def __init__(self, name, age, address, field_of_study):
        super().__init__(name, age, address)
        self.field_of_study = field_of_study

    def introduce(self):
        return f"Hi, I'm {self.name}, {self.age} years old, studying {self.field_of_study} and living in {self.address}."

class Employee(Person):
    def __init__(self, name, age, address, company):
        super().__init__(name, age, address)
        self.company = company

    def introduce(self):
        return f"Hi, I'm {self.name}, {self.age} years old, working at {self.company} and living in {self.address}."

# Test
p = Person("Alice", 30, "Paris")
s = Student("Bob", 22, "London", "Computer Science")
e = Employee("Charlie", 35, "Berlin", "Google")

print(p.introduce())
print(s.introduce())
print(e.introduce())
# Out:
# Hi, I'm Alice, 30 years old, living in Paris.
# Hi, I'm Bob, 22 years old, studying Computer Science and living in London.
# Hi, I'm Charlie, 35 years old, working at Google and living in Berlin.

# %% [markdown]
# ## Problem 3: BankAccount and SavingsAccount

# %%
class BankAccount:
    def __init__(self, account_number, balance=0):
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance")
            return False
        self.balance -= amount
        return True

    def transfer(self, destination, amount):
        if amount > self.balance:
            return False
        self.withdraw(amount)
        destination.deposit(amount)
        return True

class SavingsAccount(BankAccount):
    def __init__(self, account_number, balance=0, interest_rate=0.05):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate

    def add_interest(self):
        interest = self.balance * self.interest_rate
        self.deposit(interest)
        return interest

    def check_balance(self):
        return f"Account {self.account_number}: balance = {self.balance:.2f}"

# Test
a1 = BankAccount("001", 1000)
a2 = SavingsAccount("002", 500, 0.1)

print(f"a1 balance: {a1.balance}")
print(f"a2 balance: {a2.balance}")

a1.transfer(a2, 200)
print(f"\nAfter a1 transfers 200 to a2:")
print(f"a1 balance: {a1.balance}")
print(a2.check_balance())

interest = a2.add_interest()
print(f"\nInterest added: {interest:.2f}")
print(a2.check_balance())

print(f"\nTransfer 10000 from a1 to a2: {a1.transfer(a2, 10000)}")
# Out:
# a1 balance: 1000
# a2 balance: 500
#
# After a1 transfers 200 to a2:
# a1 balance: 800
# Account 002: balance = 700.00
#
# Interest added: 70.00
# Account 002: balance = 770.00
#
# Transfer 10000 from a1 to a2: False
